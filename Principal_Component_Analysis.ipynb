# %%
from sklearn.datasets import load_breast_cancer
from sklearn.model_selection import train_test_split
from sklearn.decomposition import PCA
import pandas as pd

# %%
can=load_breast_cancer()
cancer=pd.DataFrame(can.data,columns=can.feature_names)
cancer.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
cancer.shape
# Out:
# (569, 30)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scale=MinMaxScaler()

# %%
cancer=scale.fit_transform(cancer)

# %%
cancer_df=pd.DataFrame(cancer,columns=can.feature_names)

# %%
cancer_df.head()
# Out:
#    mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0     0.521037      0.022658        0.545989   0.363733         0.593753
# 1     0.643144      0.272574        0.615783   0.501591         0.289880
# 2     0.601496      0.390260        0.595743   0.449417         0.514309
# 3     0.210090      0.360839        0.233501   0.102906         0.811321
# 4     0.629893      0.156578        0.630986   0.489290         0.430351
#
#    mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0          0.792037        0.703140             0.731113       0.686364
# 1          0.181768        0.203608             0.348757       0.379798
# 2          0.431017        0.462512             0.635686       0.509596
# 3          0.811361        0.565604             0.522863       0.776263
# 4          0.347893        0.463918             0.518390       0.378283
#
#    mean fractal dimension  ...  worst radius  worst texture  worst perimeter  \
# ...

# %%
principal=PCA(n_components=5)
new_df=principal.fit_transform(cancer_df)

# %%
new_df=pd.DataFrame(new_df)
new_df.head()
# Out:
#           0         1         2         3         4
# 0  1.387021  0.426895 -0.541702  0.048484 -0.072199
# 1  0.462308 -0.556947 -0.205175 -0.042830  0.016111
# 2  0.954621 -0.109701 -0.147848 -0.001068 -0.033798
# 3  1.000816  1.525089 -0.053271 -0.207916 -0.219381
# 4  0.626828 -0.302471 -0.409336  0.238811 -0.002192

# %%
X_train,X_test,y_train,y_test=train_test_split(new_df,can.target,test_size=0.3,random_state=100)
X_train.shape,X_test.shape
# Out:
# ((398, 5), (171, 5))

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
model=RandomForestClassifier(random_state=100)

# %%
model.fit(X_train,y_train)
# Out:
# RandomForestClassifier(random_state=100)

# %%
y_pred=model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test,y_pred)
# Out:
# 0.9766081871345029
